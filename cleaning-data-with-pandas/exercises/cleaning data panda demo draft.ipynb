# %%
import os
import pandas as pd

# 你的 CSV 文件名
filename = "student_records_dirty.csv"

# 1️⃣ 查看当前工作目录
cwd = os.getcwd()
print("当前工作目录:", cwd)

# 2️⃣ 查看当前目录所有文件
files = os.listdir()
print("当前目录文件列表:", files)

# 3️⃣ 检查 CSV 是否存在
if filename in files:
    print(f"✅ 找到文件 {filename}，开始读取...")
    
    # 4️⃣ 读取 CSV
    try:
        df = pd.read_csv(filename)
        
        # 5️⃣ 显示 CSV 信息
        print("\nCSV 数据基本信息:")
        print(df.info())
        
        print("\n前 5 行数据:")
